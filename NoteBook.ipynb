# %% [markdown]
# ## Importing Libraries
# json and os are used to read files
# matplotlib and seaborn is used to plot data and imges
# cv2 and PIL is used for image processing
# sklearn is used to select random images for train and test data
# tensorflow and keras are used to build neural networks
# scipy is used for image processing

# %%
import json, os
import numpy as np
import matplotlib.pyplot as plt
import cv2 , PIL
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import keras
import seaborn as sns
from scipy.signal import find_peaks

# %%
imagefiles = os.listdir("images/")
imagefiles = shuffle(imagefiles)

# %%
def resize(img):
    img = PIL.Image.fromarray(img)
    resized_im = img.resize((400,400))
    open_cv_image = np.array(resized_im) 
    return open_cv_image

# %%
N = 20000

# %% [markdown]
# ## Reading Images from train/images folder

# %%
X = []
Y = []

img = np.array(imagefiles)[np.random.randint(low=0,high=len(imagefiles),size=N)]
for i in list(img):
    img = cv2.imread(f"images/{i}",0)
    X.append(img)
    f = open(f"annotations/{i[:-4]}.json")
    l = json.load(f)
    Y.append(l["chart-type"])

# %%
Y = np.array(Y)
U = np.unique(Y)
for i in range(U.shape[0]):
    Y[Y == U[i]] = i
Y = Y.astype(int)

# %%
for i in range(U.shape[0]):
    print(U[i],Y[Y == i].shape[0])
sns.set(style="whitegrid")
plt.pie(list(Y[Y == i].shape[0] for i in range(U.shape[0])), labels=U)  
plt.show()
# Out:
# dot 1735
# line 8018
# scatter 3812
# vertical_bar 6435

# %% [markdown]
# ## Extract Graph from Img

# %%
def GraphExtract(img,h=150):
    imgEdges = cv2.Canny(img,threshold1=20,threshold2=40)
    l = np.mean(imgEdges,axis=0)
    firstPeaks = find_peaks(l[15:],prominence = h)[0]
    if(len(firstPeaks) != 0 and firstPeaks[0] < l.shape[0] / 2): 
        return img[:,firstPeaks[0]+15:]
    else:
        return GraphExtract(img,h*.8)    
    
def preprocessing(img):
    if(np.mean(img) < 100): img = ~img
    imgY = GraphExtract(img[::-1].T).T[::-1]
    imgX = GraphExtract(imgY,h=118)
    imgX = imgX[int(imgX.shape[0]*.3):,:]
    return (imgX, cv2.Canny(img,threshold1=20,threshold2=70))

# %% [markdown]
# ### Example

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.imshow(X[0],cmap='gray')
plt.title("Actual")

plt.subplot(1,2,2)
plt.imshow(preprocessing(X[0])[0],cmap='gray')
plt.title("Extracted")

plt.show()

# %% [markdown]
# ## Making Features Vector from Images

# %%
def makeVector(img):
    imgs = preprocessing(img)
    img = imgs[0]
    y = np.mean(img,axis=0)
    x = np.mean(img,axis=1)
    f = np.abs(np.fft.rfft(y[10:-10]).real[10:-10])
    g = np.abs(np.fft.rfft(x[10:-10]).real[10:-10])
    l1 = [np.std(img),
         np.mean(y),
         np.std(y),
         np.mean(x),
         np.std(x),
         np.where(f == np.max(f))[0][0],
         np.max(f),
         np.mean(f),
         np.std(f),
         np.std(g),
         np.mean(g),
         np.where(g == np.max(g))[0][0],
         np.max(g),
    ]
    img = imgs[1]
    y = np.mean(img,axis=0)
    x = np.mean(img,axis=1)
    f = np.abs(np.fft.rfft(y[10:-10]).real[10:-10])
    g = np.abs(np.fft.rfft(x[10:-10]).real[10:-10])
    l2 = [np.std(img),
         np.mean(y),
         np.std(y),
         np.mean(x),
         np.std(x),
         np.where(f == np.max(f))[0][0],
         np.max(f),
         np.mean(f),
         np.std(f),
         np.std(g),
         np.mean(g),
         np.where(g == np.max(g))[0][0],
         np.max(g),
    ]    
    
    return np.array(list(l1+l2))

# %% [markdown]
# ### Converting Images to Features Vectors

# %%
X_ = []
Y_ = []
for i in range(len(X)):
    X_.append(makeVector(X[i]))
    Y_.append(Y[i])
    
X_ = np.array(X_)
Y_ = np.array(Y_)

# %%
print("X shape :",X_.shape)
print("Y shape :",Y_.shape)
# Out:
# X shape : (20000, 26)
# Y shape : (20000,)

# %% [markdown]
# ### Seperating training and test samples

# %%
x_train, x_test, y_train, y_test = train_test_split(X_,Y_,test_size=.3)  
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ### Neutral Networks

# %%
model = keras.Sequential([
    keras.Input(shape=x_train[0].shape),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(32,activation='relu'),
    keras.layers.Dense(U.shape[0],activation='softmax')
])

# %%
y_train = np.int32(y_train)
model.compile(optimizer=keras.optimizers.Adam(.001),loss='sparse_categorical_crossentropy')
model.fit(x=x_train,y=y_train,epochs=50)
model.compile(optimizer=keras.optimizers.Adam(.0001),loss='sparse_categorical_crossentropy')
model.fit(x=x_train,y=y_train,epochs=50)
# Out:
# Epoch 1/50
# 438/438 [==============================] - 1s 622us/step - loss: 10.2009
# Epoch 2/50
# 438/438 [==============================] - 0s 647us/step - loss: 1.6267
# Epoch 3/50
# 438/438 [==============================] - 0s 624us/step - loss: 1.4181
# Epoch 4/50
# 438/438 [==============================] - 0s 588us/step - loss: 1.2876
# Epoch 5/50
# 438/438 [==============================] - 0s 616us/step - loss: 1.1434
# Epoch 6/50
# 438/438 [==============================] - 0s 618us/step - loss: 1.0184
# Epoch 7/50
# 438/438 [==============================] - 0s 589us/step - loss: 1.0381
# Epoch 8/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.8396
# Epoch 9/50
# 438/438 [==============================] - 0s 628us/step - loss: 1.0072
# Epoch 10/50
# 438/438 [==============================] - 0s 593us/step - loss: 0.7123
# Epoch 11/50
# 438/438 [==============================] - 0s 593us/step - loss: 0.5563
# Epoch 12/50
# 438/438 [==============================] - 0s 601us/step - loss: 0.5032
# Epoch 13/50
# 438/438 [==============================] - 0s 625us/step - loss: 0.5709
# Epoch 14/50
# 438/438 [==============================] - 0s 590us/step - loss: 0.5046
# Epoch 15/50
# 438/438 [==============================] - 0s 589us/step - loss: 0.5427
# Epoch 16/50
# 438/438 [==============================] - 0s 585us/step - loss: 0.4721
# Epoch 17/50
# 438/438 [==============================] - 0s 643us/step - loss: 0.4934
# Epoch 18/50
# 438/438 [==============================] - 0s 591us/step - loss: 0.3240
# Epoch 19/50
# 438/438 [==============================] - 0s 592us/step - loss: 0.3540
# Epoch 20/50
# 438/438 [==============================] - 0s 590us/step - loss: 0.3502
# Epoch 21/50
# 438/438 [==============================] - 0s 634us/step - loss: 0.3158
# Epoch 22/50
# 438/438 [==============================] - 0s 586us/step - loss: 0.3018
# Epoch 23/50
# 438/438 [==============================] - 0s 589us/step - loss: 0.2590
# Epoch 24/50
# 438/438 [==============================] - 0s 587us/step - loss: 0.2750
# Epoch 25/50
# 438/438 [==============================] - 0s 624us/step - loss: 0.3632
# Epoch 26/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.1937
# Epoch 27/50
# 438/438 [==============================] - 0s 596us/step - loss: 0.1838
# Epoch 28/50
# 438/438 [==============================] - 0s 596us/step - loss: 0.1882
# Epoch 29/50
# 438/438 [==============================] - 0s 629us/step - loss: 0.1953
# 438/438 [==============================] - 0s 596us/step - loss: 0.0261
# Epoch 22/50
# 438/438 [==============================] - 0s 596us/step - loss: 0.0261
# Epoch 23/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.0261
# Epoch 24/50
# 438/438 [==============================] - 0s 628us/step - loss: 0.0263
# Epoch 25/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.0260
# Epoch 26/50
# 438/438 [==============================] - 0s 592us/step - loss: 0.0247
# Epoch 27/50
# 438/438 [==============================] - 0s 629us/step - loss: 0.0244
# Epoch 28/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.0252
# Epoch 29/50
# 438/438 [==============================] - 0s 604us/step - loss: 0.0242
# Epoch 30/50
# 438/438 [==============================] - 0s 594us/step - loss: 0.0241
# Epoch 31/50
# 438/438 [==============================] - 0s 630us/step - loss: 0.0235
# Epoch 32/50
# 438/438 [==============================] - 0s 596us/step - loss: 0.0235
# Epoch 33/50
# 438/438 [==============================] - 0s 592us/step - loss: 0.0235
# Epoch 34/50
# 438/438 [==============================] - 0s 596us/step - loss: 0.0235
# Epoch 35/50
# 438/438 [==============================] - 0s 627us/step - loss: 0.0230
# Epoch 36/50
# 438/438 [==============================] - 0s 597us/step - loss: 0.0226
# Epoch 37/50
# 438/438 [==============================] - 0s 592us/step - loss: 0.0229
# Epoch 38/50
# 438/438 [==============================] - 0s 597us/step - loss: 0.0222
# Epoch 39/50
# 438/438 [==============================] - 0s 630us/step - loss: 0.0227
# Epoch 40/50
# 438/438 [==============================] - 0s 595us/step - loss: 0.0223
# Epoch 41/50
# 438/438 [==============================] - 0s 595us/step - loss: 0.0213
# Epoch 42/50
# 438/438 [==============================] - 0s 597us/step - loss: 0.0217
# Epoch 43/50
# 438/438 [==============================] - 0s 630us/step - loss: 0.0219
# Epoch 44/50
# 438/438 [==============================] - 0s 598us/step - loss: 0.0210
# Epoch 45/50
# 438/438 [==============================] - 0s 611us/step - loss: 0.0219
# Epoch 46/50
# 438/438 [==============================] - 0s 614us/step - loss: 0.0210
# Epoch 47/50
# 438/438 [==============================] - 0s 603us/step - loss: 0.0206
# Epoch 48/50
# 438/438 [==============================] - 0s 592us/step - loss: 0.0208
# Epoch 49/50
# 438/438 [==============================] - 0s 595us/step - loss: 0.0199
# Epoch 50/50
# 438/438 [==============================] - 0s 641us/step - loss: 0.0196

# %% [markdown]
# ## Errors

# %% [markdown]
# ### Overall Errors

# %%
y_predicted = np.argmax(model.predict(x_test),axis = 1)
errors = np.int32(y_predicted != y_test)
print("error percentage: ",np.sum(errors)/errors.shape[0])
print("accuracy percentage: ",1- np.sum(errors)/errors.shape[0])
# Out:
# 188/188 [==============================] - 0s 482us/step
# error percentage:  0.014166666666666666
# accuracy percentage:  0.9858333333333333

# %% [markdown]
# ### Percentage errors for different types of graphs

# %%
err = np.array(list(np.sum(errors[y_test == i])/np.sum(y_test == i) for i in range(U.shape[0])))
plt.bar(U,err*100)
plt.ylabel("percentage of errors for different graph")
plt.show()

# %% [markdown]
# ### Numbers of images used for testing

# %%
s = list(y_test[y_test == i].shape[0] for i in range(U.shape[0]))
for i in range(U.shape[0]):
    print(U[i]," :",s[i],)
plt.bar(U,s)
plt.show()
# Out:
# dot  : 507
# line  : 2427
# scatter  : 1113
# vertical_bar  : 1953
