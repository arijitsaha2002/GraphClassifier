# %% [markdown]
# ## Importing Libraries
# json and os are used to read files
# matplotlib and seaborn is used to plot data and imges
# cv2 and PIL is used for image processing
# sklearn is used to select random images for train and test data
# tensorflow and keras are used to build neural networks
# scipy is used for image processing

# %%
import json, os
import numpy as np
import matplotlib.pyplot as plt
import cv2 , PIL
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
import keras
import seaborn as sns
from scipy.signal import find_peaks

# %%
imagefiles = os.listdir("images/")
imagefiles = shuffle(imagefiles)

# %%
def resize(img):
    img = PIL.Image.fromarray(img)
    resized_im = img.resize((400,400))
    open_cv_image = np.array(resized_im) 
    return open_cv_image

# %%
N = 20000

# %% [markdown]
# ## Reading Images from train/images folder

# %%
X = []
Y = []

img = np.array(imagefiles)[np.random.randint(low=0,high=len(imagefiles),size=N)]
for i in list(img):
    img = cv2.imread(f"images/{i}",0)
    X.append(img)
    f = open(f"annotations/{i[:-4]}.json")
    l = json.load(f)
    Y.append(l["chart-type"])

# %%
Y = np.array(Y)
U = np.unique(Y)
for i in range(U.shape[0]):
    Y[Y == U[i]] = i
Y = Y.astype(int)

# %%
for i in range(U.shape[0]):
    print(U[i],Y[Y == i].shape[0])
sns.set(style="whitegrid")
plt.pie(list(Y[Y == i].shape[0] for i in range(U.shape[0])), labels=U)  
plt.show()
# Out:
# dot 1683
# line 8201
# scatter 3755
# vertical_bar 6361

# %% [markdown]
# ## Extract Graph from Img

# %%
def GraphExtract(img,h=150):
    imgEdges = cv2.Canny(img,threshold1=20,threshold2=40)
    l = np.mean(imgEdges,axis=0)
    firstPeaks = find_peaks(l[15:],prominence = h)[0]
    if(len(firstPeaks) != 0 and firstPeaks[0] < l.shape[0] / 2): 
        return img[:,firstPeaks[0]+15:]
    else:
        return GraphExtract(img,h*.8)    
    
def preprocessing(img):
    if(np.mean(img) < 100): img = ~img
    imgY = GraphExtract(img[::-1].T).T[::-1]
    imgX = GraphExtract(imgY,h=118)
    imgX = imgX[int(imgX.shape[0]*.3):,:]
    return (imgX, cv2.Canny(img,threshold1=20,threshold2=70))

# %% [markdown]
# ### Example

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.imshow(X[0],cmap='gray')
plt.title("Actual")

plt.subplot(1,2,2)
plt.imshow(preprocessing(X[0])[0],cmap='gray')
plt.title("Extracted")

plt.show()

# %% [markdown]
# ## Making Features Vector from Images

# %%
def makeVector(img):
    imgs = preprocessing(img)
    img = imgs[0]
    y = np.mean(img,axis=0)
    x = np.mean(img,axis=1)
    f = np.abs(np.fft.rfft(y[10:-10]).real[10:-10])
    g = np.abs(np.fft.rfft(x[10:-10]).real[10:-10])
    l1 = [np.std(img),
         np.mean(y),
         np.std(y),
         np.mean(x),
         np.std(x),
         np.where(f == np.max(f))[0][0],
         np.max(f),
         np.mean(f),
         np.std(f),
         np.std(g),
         np.mean(g),
         np.where(g == np.max(g))[0][0],
         np.max(g),
    ]
    img = imgs[1]
    y = np.mean(img,axis=0)
    x = np.mean(img,axis=1)
    f = np.abs(np.fft.rfft(y[10:-10]).real[10:-10])
    g = np.abs(np.fft.rfft(x[10:-10]).real[10:-10])
    l2 = [np.std(img),
         np.mean(y),
         np.std(y),
         np.mean(x),
         np.std(x),
         np.where(f == np.max(f))[0][0],
         np.max(f),
         np.mean(f),
         np.std(f),
         np.std(g),
         np.mean(g),
         np.where(g == np.max(g))[0][0],
         np.max(g),
    ]    
    
    return np.array(list(l1+l2))

# %% [markdown]
# ### Converting Images to Features Vectors

# %%
X_ = []
Y_ = []
for i in range(len(X)):
    X_.append(makeVector(X[i]))
    Y_.append(Y[i])
    
X_ = np.array(X_)
Y_ = np.array(Y_)

# %%
print("X shape :",X_.shape)
print("Y shape :",Y_.shape)
# Out:
# X shape : (20000, 26)
# Y shape : (20000,)

# %% [markdown]
# ### Seperating training and test samples

# %%
x_train, x_test, y_train, y_test = train_test_split(X_,Y_,test_size=.5)  
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# ### Neutral Networks

# %%
model = keras.Sequential([
    keras.Input(shape=x_train[0].shape),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dense(32,activation='relu'),
    keras.layers.Dense(U.shape[0],activation='softmax')
])

# %%
y_train = np.int32(y_train)
model.compile(optimizer=keras.optimizers.Adam(.001),loss='sparse_categorical_crossentropy')
model.fit(x=x_train,y=y_train,epochs=50)
model.compile(optimizer=keras.optimizers.Adam(.0001),loss='sparse_categorical_crossentropy')
model.fit(x=x_train,y=y_train,epochs=50)
# Out:
# Epoch 1/50
# 313/313 [==============================] - 1s 782us/step - loss: 6.2660
# Epoch 2/50
# 313/313 [==============================] - 0s 781us/step - loss: 1.6406
# Epoch 3/50
# 313/313 [==============================] - 0s 799us/step - loss: 1.2426
# Epoch 4/50
# 313/313 [==============================] - 0s 859us/step - loss: 0.9834
# Epoch 5/50
# 313/313 [==============================] - 0s 740us/step - loss: 0.8787
# Epoch 6/50
# 313/313 [==============================] - 0s 742us/step - loss: 0.6797
# Epoch 7/50
# 313/313 [==============================] - 0s 736us/step - loss: 0.7562
# Epoch 8/50
# 313/313 [==============================] - 0s 729us/step - loss: 0.6765
# Epoch 9/50
# 313/313 [==============================] - 0s 898us/step - loss: 0.5579
# Epoch 10/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.7571
# Epoch 11/50
# 313/313 [==============================] - 0s 816us/step - loss: 0.4956
# Epoch 12/50
# 313/313 [==============================] - 0s 869us/step - loss: 0.4622
# Epoch 13/50
# 313/313 [==============================] - 0s 732us/step - loss: 0.4659
# Epoch 14/50
# 313/313 [==============================] - 0s 749us/step - loss: 0.3812
# Epoch 15/50
# 313/313 [==============================] - 0s 761us/step - loss: 0.3597
# Epoch 16/50
# 313/313 [==============================] - 0s 798us/step - loss: 0.3251
# Epoch 17/50
# 313/313 [==============================] - 0s 733us/step - loss: 0.4361
# Epoch 18/50
# 313/313 [==============================] - 0s 739us/step - loss: 0.3030
# Epoch 19/50
# 313/313 [==============================] - 0s 749us/step - loss: 0.2502
# Epoch 20/50
# 313/313 [==============================] - 0s 737us/step - loss: 0.2250
# Epoch 21/50
# 313/313 [==============================] - 0s 790us/step - loss: 0.2928
# Epoch 22/50
# 313/313 [==============================] - 0s 795us/step - loss: 0.2279
# Epoch 23/50
# 313/313 [==============================] - 0s 755us/step - loss: 0.1844
# Epoch 24/50
# 313/313 [==============================] - 0s 735us/step - loss: 0.1982
# Epoch 25/50
# 313/313 [==============================] - 0s 858us/step - loss: 0.2005
# Epoch 26/50
# 313/313 [==============================] - 0s 774us/step - loss: 0.1644
# Epoch 27/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1757
# Epoch 28/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1558
# Epoch 29/50
# 313/313 [==============================] - 0s 899us/step - loss: 0.1499
# Epoch 30/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1320
# Epoch 31/50
# 313/313 [==============================] - 0s 766us/step - loss: 0.1424
# Epoch 32/50
# 313/313 [==============================] - 0s 808us/step - loss: 0.1457
# Epoch 33/50
# 313/313 [==============================] - 0s 763us/step - loss: 0.1223
# Epoch 34/50
# 313/313 [==============================] - 0s 844us/step - loss: 0.1313
# Epoch 35/50
# 313/313 [==============================] - 0s 742us/step - loss: 0.1211
# Epoch 36/50
# 313/313 [==============================] - 0s 797us/step - loss: 0.1209
# Epoch 37/50
# 313/313 [==============================] - 0s 737us/step - loss: 0.1372
# Epoch 38/50
# 313/313 [==============================] - 0s 831us/step - loss: 0.1157
# Epoch 39/50
# 313/313 [==============================] - 0s 718us/step - loss: 0.0971
# Epoch 40/50
# 313/313 [==============================] - 0s 770us/step - loss: 0.1046
# Epoch 41/50
# 313/313 [==============================] - 0s 751us/step - loss: 0.0980
# Epoch 42/50
# 313/313 [==============================] - 0s 728us/step - loss: 0.1090
# Epoch 43/50
# 313/313 [==============================] - 0s 729us/step - loss: 0.0949
# Epoch 44/50
# 313/313 [==============================] - 0s 775us/step - loss: 0.0803
# Epoch 45/50
# 313/313 [==============================] - 0s 757us/step - loss: 0.0985
# Epoch 46/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1019
# Epoch 47/50
# 313/313 [==============================] - 0s 763us/step - loss: 0.0883
# Epoch 48/50
# 313/313 [==============================] - 0s 784us/step - loss: 0.0834
# Epoch 49/50
# 313/313 [==============================] - 0s 758us/step - loss: 0.1140
# Epoch 50/50
# 313/313 [==============================] - 0s 763us/step - loss: 0.0766
# Epoch 1/50
# 313/313 [==============================] - 0s 771us/step - loss: 0.0500
# Epoch 2/50
# 313/313 [==============================] - 0s 786us/step - loss: 0.0436
# Epoch 3/50
# 313/313 [==============================] - 0s 768us/step - loss: 0.0422
# Epoch 4/50
# 313/313 [==============================] - 0s 723us/step - loss: 0.0405
# Epoch 5/50
# 313/313 [==============================] - 0s 795us/step - loss: 0.0398
# Epoch 6/50
# 313/313 [==============================] - 0s 773us/step - loss: 0.0390
# Epoch 7/50
# 313/313 [==============================] - 0s 732us/step - loss: 0.0381
# Epoch 8/50
# 313/313 [==============================] - 0s 765us/step - loss: 0.0375
# Epoch 9/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0379
# Epoch 10/50
# 313/313 [==============================] - 0s 760us/step - loss: 0.0367
# Epoch 11/50
# 313/313 [==============================] - 0s 775us/step - loss: 0.0366
# Epoch 12/50
# 313/313 [==============================] - 0s 794us/step - loss: 0.0354
# Epoch 13/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0352
# Epoch 14/50
# 313/313 [==============================] - 0s 704us/step - loss: 0.0356
# Epoch 15/50
# 313/313 [==============================] - 0s 781us/step - loss: 0.0347
# Epoch 16/50
# 313/313 [==============================] - 0s 726us/step - loss: 0.0347
# Epoch 17/50
# 313/313 [==============================] - 0s 854us/step - loss: 0.0338
# Epoch 18/50
# 313/313 [==============================] - 0s 992us/step - loss: 0.0337
# Epoch 19/50
# 313/313 [==============================] - 0s 774us/step - loss: 0.0328
# Epoch 20/50
# 313/313 [==============================] - 0s 779us/step - loss: 0.0326
# Epoch 21/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0317
# Epoch 22/50
# 313/313 [==============================] - 0s 773us/step - loss: 0.0311
# Epoch 23/50
# 313/313 [==============================] - 0s 795us/step - loss: 0.0319
# Epoch 24/50
# 313/313 [==============================] - 0s 784us/step - loss: 0.0303
# Epoch 25/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0307
# Epoch 26/50
# 186/313 [================>.............] - ETA: 0s - loss: 0.0287

# %% [markdown]
# ## Errors

# %%
y_predicted = np.argmax(model.predict(x_test),axis = 1)
errors = np.int32(y_predicted != y_test)
print("error percentage: ",np.sum(errors)/errors.shape[0])
print("accuracy percentage: ",1- np.sum(errors)/errors.shape[0])

# %%
err = list(np.sum(errors[y_test == i])/np.sum(y_test == i) for i in range(U.shape[0]))
plt.bar(U,err*100)
plt.ylabel("percentage of errors for different graph")
plt.show()

# %%
s = list(y_test[y_test == i].shape[0] for i in range(U.shape[0]))
for i in range(U.shape[0]):
    print(U[i]," :",s[i],)
plt.bar(U,s)
plt.show()
